# %%
# ====================================================== # 100nM Arijit R-Loop

folder_path = r"C:\Users\leogd\Desktop\EMSA_Image_J_Analysis\12092021_FMRP_Cysless_C_IDR_and_Arijit_R_Loop_Concentration_Gradient\100nM"

#gel_layout = [0,'b',19.53125,39.0625,78.125,156.25,312.5,625,1250,2500,5000,'b']
#gel_layout = [0,'b',3.90625,7.8125,15.625,31.25,62.5,125,250,500,1000,'b']
#gel_layout = [0,'b',10,50,100,250,500,1000,2500,5000,'b']
#gel_layout = [0,'b',1,5,10,50,100,500,1000,5000,'b']
gel_layout = [0,'b',5,50,500,5000]



#Enter either:
#a) protein concentrations (numbers)
#b) Backgroung or background or b for background data

Protein_name = 'FMRP C-IDR'

Substrate_name = "Arijit R-Loop"

Substrate_concentration = 100

Concentration_unit = 'nM'

# ====================================================== #

from Gel_Shift_ImageJ_Analysis_as_functions import *

# ====================================================== #

(KD,titrations,avg_fraction_bound,SD_fraction_bound) = Calculate_KD_ImageJ_Gel_Shift(folder_path,gel_layout,Protein_name,Substrate_name,Substrate_concentration,Concentration_unit)
# Out:
# Loading data...
#
#
# 12092021_FMRP_Cysless_C_IDR_and_Arijit_R_Loop_Concentrations_100nM_measured
#
#
# Data successfully loaded!
#
#
# # ====================================================== #
#
#
# The calculated KD is: 1787.77781467 nM

# %%
# ====================================================== # 50nM Arijit R-Loop

folder_path = r"C:\Users\leogd\Desktop\EMSA_Image_J_Analysis\12092021_FMRP_Cysless_C_IDR_and_Arijit_R_Loop_Concentration_Gradient\50nM"

#gel_layout = [0,'b',19.53125,39.0625,78.125,156.25,312.5,625,1250,2500,5000,'b']
#gel_layout = [0,'b',3.90625,7.8125,15.625,31.25,62.5,125,250,500,1000,'b']
#gel_layout = [0,'b',10,50,100,250,500,1000,2500,5000,'b']
#gel_layout = [0,'b',1,5,10,50,100,500,1000,5000,'b']
gel_layout = [0,'b',5,50,500,5000]



#Enter either:
#a) protein concentrations (numbers)
#b) Backgroung or background or b for background data

Protein_name = 'FMRP C-IDR'

Substrate_name = "Arijit R-Loop"

Substrate_concentration = 50

Concentration_unit = 'nM'

# ====================================================== #

from Gel_Shift_ImageJ_Analysis_as_functions import *

# ====================================================== #

(KD,titrations,avg_fraction_bound,SD_fraction_bound) = Calculate_KD_ImageJ_Gel_Shift(folder_path,gel_layout,Protein_name,Substrate_name,Substrate_concentration,Concentration_unit)
# Out:
# Loading data...
#
#
# 12092021_FMRP_Cysless_C_IDR_and_Arijit_R_Loop_Concentrations_50nM_measured
#
#
# Data successfully loaded!
#
#
# # ====================================================== #
#
#
# The calculated KD is: 1442.31550385 nM

# %%
# ====================================================== # 10nM Arijit R-Loop

folder_path = r"C:\Users\leogd\Desktop\EMSA_Image_J_Analysis\12092021_FMRP_Cysless_C_IDR_and_Arijit_R_Loop_Concentration_Gradient\10nM"

#gel_layout = [0,'b',19.53125,39.0625,78.125,156.25,312.5,625,1250,2500,5000,'b']
#gel_layout = [0,'b',3.90625,7.8125,15.625,31.25,62.5,125,250,500,1000,'b']
#gel_layout = [0,'b',10,50,100,250,500,1000,2500,5000,'b']
#gel_layout = [0,'b',1,5,10,50,100,500,1000,5000,'b']
gel_layout = [0,'b',5,50,500,5000]



#Enter either:
#a) protein concentrations (numbers)
#b) Backgroung or background or b for background data

Protein_name = 'FMRP C-IDR'

Substrate_name = "Arijit R-Loop"

Substrate_concentration = 10

Concentration_unit = 'nM'

# ====================================================== #

from Gel_Shift_ImageJ_Analysis_as_functions import *

# ====================================================== #

(KD,titrations,avg_fraction_bound,SD_fraction_bound) = Calculate_KD_ImageJ_Gel_Shift(folder_path,gel_layout,Protein_name,Substrate_name,Substrate_concentration,Concentration_unit)
# Out:
# Loading data...
#
#
# 12092021_FMRP_Cysless_C_IDR_and_Arijit_R_Loop_Concentrations_10nM_measured
#
#
# Data successfully loaded!
#
#
# # ====================================================== #
#
#
# The calculated KD is: 384.75196442 nM

# %%
# ====================================================== # 5nM Arijit R-Loop

folder_path = r"C:\Users\leogd\Desktop\EMSA_Image_J_Analysis\12092021_FMRP_Cysless_C_IDR_and_Arijit_R_Loop_Concentration_Gradient\5nM"

#gel_layout = [0,'b',19.53125,39.0625,78.125,156.25,312.5,625,1250,2500,5000,'b']
#gel_layout = [0,'b',3.90625,7.8125,15.625,31.25,62.5,125,250,500,1000,'b']
#gel_layout = [0,'b',10,50,100,250,500,1000,2500,5000,'b']
#gel_layout = [0,'b',1,5,10,50,100,500,1000,5000,'b']
gel_layout = [0,'b',5,50,500,5000]



#Enter either:
#a) protein concentrations (numbers)
#b) Backgroung or background or b for background data

Protein_name = 'FMRP C-IDR'

Substrate_name = "Arijit R-Loop"

Substrate_concentration = 5

Concentration_unit = 'nM'

# ====================================================== #

from Gel_Shift_ImageJ_Analysis_as_functions import *

# ====================================================== #

(KD,titrations,avg_fraction_bound,SD_fraction_bound) = Calculate_KD_ImageJ_Gel_Shift(folder_path,gel_layout,Protein_name,Substrate_name,Substrate_concentration,Concentration_unit)
# Out:
# Loading data...
#
#
# 12092021_FMRP_Cysless_C_IDR_and_Arijit_R_Loop_Concentrations_5nM_measured
#
#
# Data successfully loaded!
#
#
# # ====================================================== #
#
#
# The calculated KD is: 60.16273343 nM

# %%
# ====================================================== #

folder_path = r"C:\Users\leogd\Desktop\EMSA_Image_J_Analysis\01082021_FMRP_558_R_Loop_Binding"

#gel_layout = [0,'b',19.53125,39.0625,78.125,156.25,312.5,625,1250,2500,5000,'b']
#gel_layout = [0,'b',3.90625,7.8125,15.625,31.25,62.5,125,250,500,1000,'b']
gel_layout = [0,'b',10,50,100,250,500,1000,2500,5000,'b']
#gel_layout = [0,'b',1,5,10,50,100,500,1000,5000,'b']



#Enter either:
#a) protein concentrations (numbers)
#b) Backgroung or background or b for background data

Protein_name = 'FMRP 558'

Substrate_name = "R-Loop"

Substrate_concentration = 50

Concentration_unit = 'nM'

# ====================================================== #

from Gel_Shift_ImageJ_Analysis_as_functions import *

# ====================================================== #

(KD,titrations,avg_fraction_bound,SD_fraction_bound) = Calculate_KD_ImageJ_Gel_Shift(folder_path,gel_layout,Protein_name,Substrate_name,Substrate_concentration,Concentration_unit)
# Out:
# Loading data...
#
#
# 01082021_FMRP_558_R_Loop_Binding_5+_destain_measured
#
#
# Data successfully loaded!
#
#
# # ====================================================== #
#
#
# The calculated KD is: 4169.54528592 nM

# %%
# ====================================================== #

folder_path = r"C:\Users\leogd\Desktop\EMSA_Image_J_Analysis\niagara_dna_bubble"

#gel_layout = [0,'b',19.53125,39.0625,78.125,156.25,312.5,625,1250,2500,5000,'b']
#gel_layout = [0,'b',3.90625,7.8125,15.625,31.25,62.5,125,250,500,1000,'b']
#gel_layout = [0,'b',10,50,100,250,500,1000,2500,5000,'b']
gel_layout = [0,'b',1,5,10,50,100,500,1000,5000,'b']
#gel_layout = [0,'b',1,5,10,50,100,500,1000,'b']



#Enter either:
#a) protein concentrations (numbers)
#b) Backgroung or background or b for background data

Protein_name = 'FMRP C-IDR'

Substrate_name = "DNA Bubble (saturated pixels)"

Substrate_concentration = 50

Concentration_unit = 'nM'

# ====================================================== #

from Gel_Shift_ImageJ_Analysis_as_functions import *

# ====================================================== #

(KD,titrations,avg_fraction_bound,SD_fraction_bound) = Calculate_KD_ImageJ_Gel_Shift(folder_path,gel_layout,Protein_name,Substrate_name,Substrate_concentration,Concentration_unit)
# Out:
# Loading data...
#
#
# 10012021_C_IDR_Binding_DNA-Bubble_5+_destain_measured
#
#
# Data successfully loaded!
#
#
# # ====================================================== #
#
#
# The calculated KD is: 1013.6812079 nM

# %%
# ====================================================== #

folder_path = r"C:\Users\leogd\Desktop\EMSA_Image_J_Analysis\niagara_double_overhang"

#gel_layout = [0,'b',19.53125,39.0625,78.125,156.25,312.5,625,1250,2500,5000,'b']
#gel_layout = [0,'b',3.90625,7.8125,15.625,31.25,62.5,125,250,500,1000,'b']
#gel_layout = [0,'b',10,50,100,250,500,1000,2500,5000,'b']
gel_layout = [0,'b',1,5,10,50,100,500,1000,5000,'b']



#Enter either:
#a) protein concentrations (numbers)
#b) Backgroung or background or b for background data

Protein_name = 'FMRP C-IDR'

Substrate_name = "Double Overhang (saturated pixels)"

Substrate_concentration = 50

Concentration_unit = 'nM'

# ====================================================== #

from Gel_Shift_ImageJ_Analysis_as_functions import *

# ====================================================== #

(KD,titrations,avg_fraction_bound,SD_fraction_bound) = Calculate_KD_ImageJ_Gel_Shift(folder_path,gel_layout,Protein_name,Substrate_name,Substrate_concentration,Concentration_unit)
# Out:
# Loading data...
#
#
# 10012021_C_IDR_Binding_Double-OVH_5+_destain_measured
#
#
# Data successfully loaded!
#
#
# # ====================================================== #
#
#
# The calculated KD is: 4345.69255053 nM

# %%
# ====================================================== #

folder_path = r"C:\Users\leogd\Desktop\EMSA_Image_J_Analysis\11192021_FMRP_C_IDR_Arijit_R_loop_30_min_ice_incubation_lower_R_Loop_concentration"

gel_layout = [0,'b',8,40,200,1000]
#gel_layout = [0,'b',3.90625,7.8125,15.625,31.25,62.5,125,250,500,1000,'b']
#gel_layout = [0,'b',10,50,100,250,500,1000,2500,5000,'b']

#Enter either:
#a) protein concentrations (numbers)
#b) Backgroung or background or b for background data

Protein_name = 'FMRP C-IDR'

Substrate_name = "Arijit R-Loop (5nM)"

Substrate_concentration = 5

Concentration_unit = 'nM'

# ====================================================== #

from Gel_Shift_ImageJ_Analysis_as_functions import *

# ====================================================== #

(KD,titrations,avg_fraction_bound,SD_fraction_bound) = Calculate_KD_ImageJ_Gel_Shift(folder_path,gel_layout,Protein_name,Substrate_name,Substrate_concentration,Concentration_unit)
# Out:
# Loading data...
#
#
# 11192021_FMRP_C_IDR_Arijit_R_loop_30_min_ice_incubation_lower_R_Loop_concentration_10_min_stain_faint_bands_exposure_measured
#
#
# Data successfully loaded!
#
#
# # ====================================================== #
#
#
# The calculated KD is: 82.01472005 nM

# %%
# ====================================================== #

folder_path = r"C:\Users\leogd\Desktop\EMSA_Image_J_Analysis\Extra_backgrounds"

gel_layout = [0,'b',8,40,200,1000,'b','b','b','b']
#gel_layout = [0,'b',3.90625,7.8125,15.625,31.25,62.5,125,250,500,1000,'b']
#gel_layout = [0,'b',10,50,100,250,500,1000,2500,5000,'b']

#Enter either:
#a) protein concentrations (numbers)
#b) Backgroung or background or b for background data

Protein_name = 'FMRP C-IDR'

Substrate_name = "Arijit R-Loop (5nM)"

Substrate_concentration = 5

Concentration_unit = 'nM'

# ====================================================== #

from Gel_Shift_ImageJ_Analysis_as_functions import *

# ====================================================== #

(KD,titrations,avg_fraction_bound,SD_fraction_bound) = Calculate_KD_ImageJ_Gel_Shift(folder_path,gel_layout,Protein_name,Substrate_name,Substrate_concentration,Concentration_unit)
# Out:
# Loading data...
#
#
# 11192021_FMRP_C_IDR_Arijit_R_loop_30_min_ice_incubation_lower_R_Loop_concentration_10_min_stain_faint_bands_exposure_measured_extra_backgrounds
#
#
# Data successfully loaded!
#
#
# # ====================================================== #
#
#
# The calculated KD is: 137.74125048 nM

# %%
print(titrations)
print(avg_fraction_bound)
print(SD_fraction_bound)
print(KD)
