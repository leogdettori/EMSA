# %%
# ====================================================== # 10nM Glass R-Loop

folder_path = r"C:\Users\leogd\Desktop\Alex_Gels\10212022_DDX21_N_IDR_and_10nM_R_Loops/final"
#folder_path = r"C:\Users\leogd\Desktop\Final_EMSA_data\DDX21_N_IDR_10nM_R_Loop"

#gel_layout = [0,'b',78.125,156.25,312.5,625,1250,2500,5000,10000,20000,'b']
#gel_layout = [0,'b',19.53125,39.0625,78.125,156.25,312.5,625,1250,2500,5000,'b']
gel_layout = [0,'b',19.53125,39.0625,78.125,156.25,312.5,625,1250,2500,5000,'b']
#gel_layout = [0,'b',3.90625,7.8125,15.625,31.25,62.5,125,250,500,1000,'b']
#gel_layout = [0,'b',10,50,100,250,500,1000,2500,5000,'b']
#gel_layout = [0,'b',1,5,10,50,100,500,1000,5000,'b']
#gel_layout = [0,'b',5,50,500,5000]

#Background types: (possibilities provided below)
#Background with lowest intensity
background_type = 'low'
#Background with highest intensity
#background_type = 'high'
#Average of all backgrounds
#background_type = 'avg'
#First of all backgrounds
#background_type = 'first'
#Last of all backgrounds
#background_type = 'last'

#Enter either:
#a) protein concentrations (numbers)
#b) Backgroung or background or b for background data

Protein_name = 'DDX21 N-IDR'

Substrate_name = "R-Loop"

Substrate_concentration = 10

Concentration_unit = 'nM'

#Method = '1_to_1'

#For Hill-Langmuir 1 to n Method use the following:
Method = {'name':[],'initial_n':[],'n_step':[],'final_n':[]}

Method['name'] = ('Hill_Langmuir')
Method['initial_n'] = 0
Method['n_step'] = 0.01
Method['final_n'] = 5

# ====================================================== #

from Gel_Shift_ImageJ_Analysis_as_functions import *

# ====================================================== #

DDX21_N_IDR_10nM_R_Loops = Calculate_KD_ImageJ_Gel_Shift(folder_path,gel_layout,Protein_name,Substrate_name,Substrate_concentration,Concentration_unit,background_type,Method)


#(KD,titrations,avg_fraction_bound,SD_fraction_bound)
#(R2_final,KD_final,KD_SD_final,theta_final,theta_SD_final,L_final,n_final)
# Out:
# Loading data...
#
#
# 03152022_DDX21_N_IDR_10nM_Arijit_R_Loop_run_2h_10+_destain_1_measured
#
#
# Data successfully loaded!
#
#
# # ====================================================== #
#
#
# Loading data...
#
#
# 03152022_DDX21_N_IDR_10nM_Arijit_R_Loop_run_2h_10+_destain_2_measured
#
#
# Data successfully loaded!
#
#
# # ====================================================== #
#
#
# Loading data...
#
#
# 1_measured
#
#
# Data successfully loaded!
#
#
# # ====================================================== #
# Best n is:0.2800000000000001
#
#
# The calculated KD is: 3.53025311 +- 0.45083178238882793nM
# RSS: 0.045044788072073336
# R2: 0.9141230169417206

# %%
# ====================================================== # 192nM 08/20 R-Loop

#folder_path = r"C:\Users\leogd\Desktop\Alex_Gels\10252022_DDX21_N_IDR_and_190nM_R_Loops"
folder_path = r"C:\Users\leogd\Desktop\Final_EMSA_data\DDX21_N_IDR_192nM_R_Loop"

gel_layout = [0,'b',435.1679688,870.3359375,1740.671875,3481.34375,6962.6875,13925.375,27850.75,55701.5,111403,'b']
#gel_layout = [0,'b',19.53125,39.0625,78.125,156.25,312.5,625,1250,2500,5000,'b']
#gel_layout = [0,'b',19.53125,39.0625,78.125,156.25,312.5,625,1250,2500,5000,'b']
#gel_layout = [0,'b',3.90625,7.8125,15.625,31.25,62.5,125,250,500,1000,'b']
#gel_layout = [0,'b',10,50,100,250,500,1000,2500,5000,'b']
#gel_layout = [0,'b',1,5,10,50,100,500,1000,5000,'b']
#gel_layout = [0,'b',5,50,500,5000]

#Background types: (possibilities provided below)
#Background with lowest intensity
background_type = 'low'
#Background with highest intensity
#background_type = 'high'
#Average of all backgrounds
#background_type = 'avg'
#First of all backgrounds
#background_type = 'first'
#Last of all backgrounds
#background_type = 'last'

#Enter either:
#a) protein concentrations (numbers)
#b) Backgroung or background or b for background data

Protein_name = 'DDX21 N-IDR'

Substrate_name = "R-Loop"

Substrate_concentration = 192

Concentration_unit = 'nM'

#Method = '1_to_1'

#For Hill-Langmuir 1 to n Method use the following:
Method = {'name':[],'initial_n':[],'n_step':[],'final_n':[]}

Method['name'] = ('Hill_Langmuir')
Method['initial_n'] = 0
Method['n_step'] = 0.01
Method['final_n'] = 5

# ====================================================== #

from Gel_Shift_ImageJ_Analysis_as_functions import *

# ====================================================== #

DDX21_N_IDR_192nM_R_Loops = Calculate_KD_ImageJ_Gel_Shift(folder_path,gel_layout,Protein_name,Substrate_name,Substrate_concentration,Concentration_unit,background_type,Method)
# Out:
# Loading data...
#
#
# 03222022_Max_DDX21_N_IDR_190nM_Arijit_R_Loop_run_2h_no_destain_1_measured
#
#
# Data successfully loaded!
#
#
# # ====================================================== #
#
#
# Loading data...
#
#
# 03222022_Max_DDX21_N_IDR_190nM_Arijit_R_Loop_run_2h_no_destain_2_measured
#
#
# Data successfully loaded!
#
#
# # ====================================================== #
# C:\Users\leogd\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:828: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# Best n is:1.8900000000000015
#
#
# The calculated KD is: 31346270.43149688 +- 8110561.5592651nM
# RSS: 0.014529369807943103
# R2: 0.9916679579183452

# %%
# ====================================================== # 192nM 08/20 R-Loop _ 2nd Attempt

folder_path = r"C:\Users\leogd\Desktop\Alex_Gels\11032022_DDX21_N_IDR_and_190nM_R_Loops_2nd_attempt_brighter"
#folder_path = r"C:\Users\leogd\Desktop\Final_EMSA_data\DDX21_N_IDR_192nM_R_Loop"

gel_layout = [0,'b',435.1679688,870.3359375,1740.671875,3481.34375,6962.6875,13925.375,27850.75,55701.5,111403,'b']
#gel_layout = [0,'b',19.53125,39.0625,78.125,156.25,312.5,625,1250,2500,5000,'b']
#gel_layout = [0,'b',19.53125,39.0625,78.125,156.25,312.5,625,1250,2500,5000,'b']
#gel_layout = [0,'b',3.90625,7.8125,15.625,31.25,62.5,125,250,500,1000,'b']
#gel_layout = [0,'b',10,50,100,250,500,1000,2500,5000,'b']
#gel_layout = [0,'b',1,5,10,50,100,500,1000,5000,'b']
#gel_layout = [0,'b',5,50,500,5000]

#Background types: (possibilities provided below)
#Background with lowest intensity
background_type = 'low'
#Background with highest intensity
#background_type = 'high'
#Average of all backgrounds
#background_type = 'avg'
#First of all backgrounds
#background_type = 'first'
#Last of all backgrounds
#background_type = 'last'

#Enter either:
#a) protein concentrations (numbers)
#b) Backgroung or background or b for background data

Protein_name = 'DDX21 N-IDR'

Substrate_name = "R-Loop"

Substrate_concentration = 192

Concentration_unit = 'nM'

#Method = '1_to_1'

#For Hill-Langmuir 1 to n Method use the following:
Method = {'name':[],'initial_n':[],'n_step':[],'final_n':[]}

Method['name'] = ('Hill_Langmuir')
Method['initial_n'] = 0
Method['n_step'] = 0.01
Method['final_n'] = 5

# ====================================================== #

from Gel_Shift_ImageJ_Analysis_as_functions import *

# ====================================================== #

DDX21_N_IDR_192nM_R_Loops = Calculate_KD_ImageJ_Gel_Shift(folder_path,gel_layout,Protein_name,Substrate_name,Substrate_concentration,Concentration_unit,background_type,Method)
# Out:
# Loading data...
#
#
# 03222022_Max_DDX21_N_IDR_190nM_Arijit_R_Loop_run_2h_no_destain_1_measured
#
#
# Data successfully loaded!
#
#
# # ====================================================== #
#
#
# Loading data...
#
#
# 03222022_Max_DDX21_N_IDR_190nM_Arijit_R_Loop_run_2h_no_destain_2_measured
#
#
# Data successfully loaded!
#
#
# # ====================================================== #
#
#
# Loading data...
#
#
# 110322_ddx21gelshift_measured
#
#
# Data successfully loaded!
#
#
# # ====================================================== #
#
#
# Loading data...
#
#
# 2_measured
#
#
# Data successfully loaded!
#
#
# # ====================================================== #
# C:\Users\leogd\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:828: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# Best n is:1.8200000000000014
#
#
# ...
